# %%
import pandas as pd

# %%
# List of valid zip codes in Charlotte only
valid_zipcodes = [
    '28202', '28203', '28204', '28205', '28206', '28207', '28208', '28209',
    '28210', '28211', '28212', '28213', '28214', '28215', '28216', '28217',
    '28226', '28227', '28262', '28269', '28270', '28273', '28277', '28278'
]

# %%
df_incidents11 = pd.read_csv('2011_Incident (1).csv')
df_incidents11_valid = df_incidents11[df_incidents11['Zipcode'].isin(valid_zipcodes)]

df_incidents12 = pd.read_csv('2012_Incident.csv')
df_incidents12_valid = df_incidents12[df_incidents12['Zipcode'].isin(valid_zipcodes)]

df_incidents13 = pd.read_csv('2013_Incident.csv')
df_incidents13_valid = df_incidents13[df_incidents13['Zipcode'].isin(valid_zipcodes)]

df_incidents14 = pd.read_csv('2014_Incident.csv')
df_incidents14_valid = df_incidents14[df_incidents14['Zipcode'].isin(valid_zipcodes)]

df_incidents15 = pd.read_csv('2015_Incident.csv')
df_incidents15_valid = df_incidents15[df_incidents15['Zipcode'].isin(valid_zipcodes)]

df_incidents16 = pd.read_csv('2016_Incident.csv')
df_incidents16_valid = df_incidents16[df_incidents16['Zipcode'].isin(valid_zipcodes)]
# Out:
# C:\Users\Trevor\AppData\Local\Temp\ipykernel_6788\2397259115.py:10: DtypeWarning: Columns (14,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_incidents14 = pd.read_csv('2014_Incident.csv')

# %%
df_property11 = pd.read_csv('2011_Property.csv')


df_property12 = pd.read_csv('2012_Property.csv')


df_property13 = pd.read_csv('2013_Property.csv')


df_property14 = pd.read_csv('2014_Property.csv')


df_property15 = pd.read_csv('2015_Property.csv')


df_property16 = pd.read_csv('2016_Property.csv')

df_MedianEarnings = pd.read_csv('Median_Earnings_by_Industry.csv')
df_Occupation = pd.read_csv('Occupations.csv')
df_pop_income = pd.read_csv('Pop_and_Income_by_zip.csv')
df_race = pd.read_csv('Race_and_Ethnicity.csv')

# %%
# Step 1 Convert all columns in df_incidents11_valid to string data type
df_incidents11_valid = df_incidents11_valid.astype(str)
df_property11 = df_property11.astype(str)
df_MedianEarnings = df_MedianEarnings.astype(str)
df_Occupation = df_Occupation.astype(str)
df_pop_income = df_pop_income.astype(str)
df_race = df_race.astype(str)

# Step 2: Merge DataFrames using valid zip codes
merged11_data = df_incidents11_valid.merge(df_property11, on='Complaint_No', how='left')
merged11_data = merged11_data.merge(df_MedianEarnings, on='City', how='left')
merged11_data = merged11_data.merge(df_Occupation, on='City', how='left')
merged11_data = merged11_data.merge(df_pop_income, on='Zipcode', how='left')
merged11_data = merged11_data.merge(df_race, on='City', how='left')
merged11_data
# Out:
#          Complaint_No Block_No Direction  \
# 0      20110101000308     4425
# 1      20110101000700     2228
# 2      20110101001302     4027
# 3      20110101001302     4027
# 4      20110101001302     4027
# ...               ...      ...       ...
# 90548  20111010142504     7800
# 90549  20111010142800     3424
# 90550  20111010143801    14126
# 90551  20111010143802     4923        S
# 90552  20111010144002      161
#
#                                     Street_Name Street_Type    Suffix  \
# 0      EDDLEMAN                                          RD
# 1      BEATTIES FORD                                     RD
# 2      QUAIL GLENN                                       CT
# 3      QUAIL GLENN                                       CT
# 4      QUAIL GLENN                                       CT
# ...                                         ...         ...       ...
# 90548  IBM                                               DR
# ...

# %%
# Step 1 Convert all columns in df_incidents11_valid to string data type
df_incidents12_valid = df_incidents12_valid.astype(str)
df_property12 = df_property12.astype(str)
df_MedianEarnings = df_MedianEarnings.astype(str)
df_Occupation = df_Occupation.astype(str)
df_pop_income = df_pop_income.astype(str)
df_race = df_race.astype(str)

# Step 2: Merge DataFrames using valid zip codes
merged12_data = df_incidents12_valid.merge(df_property12, on='Complaint_No', how='left')
merged12_data = merged12_data.merge(df_MedianEarnings, on='City', how='left')
merged12_data = merged12_data.merge(df_Occupation, on='City', how='left')
merged12_data = merged12_data.merge(df_pop_income, on='Zipcode', how='left')
merged12_data = merged12_data.merge(df_race, on='City', how='left')
merged12_data
# Out:
#           Complaint_No Block_No Direction  \
# 0       20120616144301     9108
# 1       20120616144400     2903        N
# 2       20120616144400     2903        N
# 3       20120616144700      601        W
# 4       20120616144700      601        W
# ...                ...      ...       ...
# 289099  20121230232000      350        E
# 289100  20121230232000      350        E
# 289101  20121230232104     6517
# 289102  20121230232104     6517
# 289103  20121230235402     9309
#
#                                      Street_Name Street_Type    Suffix  \
# 0       REAMES                                            RD
# 1       DAVIDSON                                          ST
# 2       DAVIDSON                                          ST
# 3       24TH                                              ST
# 4       24TH                                              ST
# ...                                          ...         ...       ...
# ...

# %%
# Step 1 Convert all columns in df_incidents11_valid to string data type
df_incidents13_valid = df_incidents13_valid.astype(str)
df_property13 = df_property13.astype(str)
df_MedianEarnings = df_MedianEarnings.astype(str)
df_Occupation = df_Occupation.astype(str)
df_pop_income = df_pop_income.astype(str)
df_race = df_race.astype(str)

# Step 2: Merge DataFrames using valid zip codes
merged13_data = df_incidents13_valid.merge(df_property13, on='Complaint_No', how='left')
merged13_data = merged13_data.merge(df_MedianEarnings, on='City', how='left')
merged13_data = merged13_data.merge(df_Occupation, on='City', how='left')
merged13_data = merged13_data.merge(df_pop_income, on='Zipcode', how='left')
merged13_data = merged13_data.merge(df_race, on='City', how='left')
merged13_data
# Out:
#           Complaint_No Block_No Direction  \
# 0       20130101000201     9105
# 1       20130101000901
# 2       20130101001301     3201
# 3       20130101001400     5745
# 4       20130101001604     2400
# ...                ...      ...       ...
# 112869  20131230233000     1204
# 112870  20131230233000     1204
# 112871  20131230235601     4017
# 112872  20131230235601     4017
# 112873  20131230235601     4017
#
#                                      Street_Name Street_Type    Suffix  \
# 0       SPYGLASS                                          PL
# 1       EQUIPMENT                                         DR
# 2       BEATTIES FORD                                     RD
# 3       CENTRAL                                           AV
# 4       BEATTIES FORD RD.
# ...                                          ...         ...       ...
# 112869  HEATHER MIST                                      AV
# 112870  HEATHER MIST                                      AV
# ...

# %%
# Step 1 Convert all columns in df_incidents11_valid to string data type
df_incidents14_valid = df_incidents14_valid.astype(str)
df_property14 = df_property14.astype(str)
df_MedianEarnings = df_MedianEarnings.astype(str)
df_Occupation = df_Occupation.astype(str)
df_pop_income = df_pop_income.astype(str)
df_race = df_race.astype(str)

# Step 2: Merge DataFrames using valid zip codes
merged14_data = df_incidents14_valid.merge(df_property14, on='Complaint_No', how='left')
merged14_data = merged14_data.merge(df_MedianEarnings, on='City', how='left')
merged14_data = merged14_data.merge(df_Occupation, on='City', how='left')
merged14_data = merged14_data.merge(df_pop_income, on='Zipcode', how='left')
merged14_data = merged14_data.merge(df_race, on='City', how='left')
merged14_data
# Out:
#           Complaint_No Block_No Direction  \
# 0       20140101000503     9023
# 1       20140101000503     9023
# 2       20140101000503     9023
# 3       20140101000503     9023
# 4       20140101000503     9023
# ...                ...      ...       ...
# 115084  20141231234505      210        E
# 115085  20141231234804     3203
# 115086  20141231234804     3203
# 115087  20141231234805      201        N
# 115088  20141231235604     8400
#
#                                      Street_Name Street_Type    Suffix  \
# 0       ARBORGATE                                         DR
# 1       ARBORGATE                                         DR
# 2       ARBORGATE                                         DR
# 3       ARBORGATE                                         DR
# 4       ARBORGATE                                         DR
# ...                                          ...         ...       ...
# 115084  TRADE                                             ST
# ...

# %%
# Step 1 Convert all columns in df_incidents11_valid to string data type
df_incidents15_valid = df_incidents15_valid.astype(str)
df_property15 = df_property15.astype(str)
df_MedianEarnings = df_MedianEarnings.astype(str)
df_Occupation = df_Occupation.astype(str)
df_pop_income = df_pop_income.astype(str)
df_race = df_race.astype(str)

# Step 2: Merge DataFrames using valid zip codes
merged15_data = df_incidents15_valid.merge(df_property15, on='Complaint_No', how='left')
merged15_data = merged15_data.merge(df_MedianEarnings, on='City', how='left')
merged15_data = merged15_data.merge(df_Occupation, on='City', how='left')
merged15_data = merged15_data.merge(df_pop_income, on='Zipcode', how='left')
merged15_data = merged15_data.merge(df_race, on='City', how='left')
merged15_data
# Out:
#           Complaint_No Block_No Direction  \
# 0       20150101000306
# 1       20150101000306
# 2       20150101000306
# 3       20150101001001    14422
# 4       20150101001001    14422
# ...                ...      ...       ...
# 119258  20151231225501     7513
# 119259  20151231225501     7513
# 119260  20151231232801    10332
# 119261  20151231234900     3331
# 119262  20151231234900     3331
#
#                                      Street_Name Street_Type    Suffix  \
# 0       LUNENBERG                                         LN
# 1       LUNENBERG                                         LN
# 2       LUNENBERG                                         LN
# 3       CINNAMON FIELD                                    RD
# 4       CINNAMON FIELD                                    RD
# ...                                          ...         ...       ...
# 119258  BRADLOW                                           CT
# 119259  BRADLOW                                           CT
# ...

# %%
# Step 1 Convert all columns in df_incidents11_valid to string data type
df_incidents16_valid = df_incidents16_valid.astype(str)
df_property16 = df_property16.astype(str)
df_MedianEarnings = df_MedianEarnings.astype(str)
df_Occupation = df_Occupation.astype(str)
df_pop_income = df_pop_income.astype(str)
df_race = df_race.astype(str)

# Step 2: Merge DataFrames using valid zip codes
merged16_data = df_incidents16_valid.merge(df_property16, on='Complaint_No', how='left')
merged16_data = merged16_data.merge(df_MedianEarnings, on='City', how='left')
merged16_data = merged16_data.merge(df_Occupation, on='City', how='left')
merged16_data = merged16_data.merge(df_pop_income, on='Zipcode', how='left')
merged16_data = merged16_data.merge(df_race, on='City', how='left')
merged16_data
# Out:
#           Complaint_No Block_No Direction  \
# 0       20160101000006     2219
# 1       20160101000006     2219
# 2       20160101000006     2219
# 3       20160101000006     2219
# 4       20160101000101     8120        E
# ...                ...      ...       ...
# 128041  20161231235500     1314
# 128042  20161231235500     1314
# 128043  20161231235500     1314
# 128044  20161231235500     1314
# 128045  20161231235500     1314
#
#                                      Street_Name Street_Type    Suffix  \
# 0       HEATHER GLEN                                      LN
# 1       HEATHER GLEN                                      LN
# 2       HEATHER GLEN                                      LN
# 3       HEATHER GLEN                                      LN
# 4       W T HARRIS                                        BV
# ...                                          ...         ...       ...
# 128041  INTERURBAN                                        AV
# ...

# %%
combined_df = pd.concat([merged11_data, merged12_data, merged13_data, merged14_data, merged15_data, merged16_data], ignore_index=True)
combined_df
# Out:
#           Complaint_No Block_No Direction  \
# 0       20110101000308     4425
# 1       20110101000700     2228
# 2       20110101001302     4027
# 3       20110101001302     4027
# 4       20110101001302     4027
# ...                ...      ...       ...
# 854924  20161231235500     1314
# 854925  20161231235500     1314
# 854926  20161231235500     1314
# 854927  20161231235500     1314
# 854928  20161231235500     1314
#
#                                      Street_Name Street_Type    Suffix  \
# 0       EDDLEMAN                                          RD
# 1       BEATTIES FORD                                     RD
# 2       QUAIL GLENN                                       CT
# 3       QUAIL GLENN                                       CT
# 4       QUAIL GLENN                                       CT
# ...                                          ...         ...       ...
# 854924  INTERURBAN                                        AV
# ...

# %%
combined_df.columns
# Out:
# Index(['Complaint_No', 'Block_No', 'Direction', 'Street_Name', 'Street_Type',
#        'Suffix', 'Apt_No', 'City', 'State_x', 'Zipcode', 'X_Coordinate',
#        'Y_Coordinate', 'Division', 'Reported_Date', 'Location_Desc',
#        'Location_Type', 'Incident_From_Date', 'Incident_to_date', 'Place1',
#        'Place2', 'Clearance_Status', 'Clearance_Date', 'Case_Status',
#        'Reporting_Agency', 'Follow_up_Section', 'NIBRS_Hi_Class',
#        'Property_No', 'Property_type', 'Property_Desc', 'ID Gender', 'Gender',
#        'ID Industry Group', 'Industry Group', 'ID Year_x', 'Year_x',
#        'Median Earnings by Industry and Gender',
#        'Median Earnings by Industry and Gender Moe', 'ID Geography_x',
#        'Slug Geography_x', 'ID Group', 'Group', 'ID Subgroup', 'Subgroup',
#        'ID Occupation', 'Occupation', 'ID Year_y', 'Year_y', 'ID State',
#        'State_y', 'Workforce by Occupation and Gender',
# ...

# %%
combined_df.columns.str.strip()
# Out:
# Index(['Complaint_No', 'Block_No', 'Direction', 'Street_Name', 'Street_Type',
#        'Suffix', 'Apt_No', 'City', 'State_x', 'Zipcode', 'X_Coordinate',
#        'Y_Coordinate', 'Division', 'Reported_Date', 'Location_Desc',
#        'Location_Type', 'Incident_From_Date', 'Incident_to_date', 'Place1',
#        'Place2', 'Clearance_Status', 'Clearance_Date', 'Case_Status',
#        'Reporting_Agency', 'Follow_up_Section', 'NIBRS_Hi_Class',
#        'Property_No', 'Property_type', 'Property_Desc', 'ID Gender', 'Gender',
#        'ID Industry Group', 'Industry Group', 'ID Year_x', 'Year_x',
#        'Median Earnings by Industry and Gender',
#        'Median Earnings by Industry and Gender Moe', 'ID Geography_x',
#        'Slug Geography_x', 'ID Group', 'Group', 'ID Subgroup', 'Subgroup',
#        'ID Occupation', 'Occupation', 'ID Year_y', 'Year_y', 'ID State',
#        'State_y', 'Workforce by Occupation and Gender',
# ...

# %%
columns_to_keep = ['Complaint_No','NIBRS_Hi_Class','Location_Type','Incident_From_Date',' Incident_From_Time', 'Zipcode', 'Property_No', 'Property_type', 'Property_Desc', '2010 Pop', 'Workforce Growth',
                  'ID Gender', 'Median Earnings', 'Race', 'Ethnicity']

combined_df = combined_df[columns_to_keep]
combined_df
# Out:
#           Complaint_No                                     NIBRS_Hi_Class  \
# 0       20110101000308  Drug Equipment Violations                     ...
# 1       20110101000700  Aggravated Assault                            ...
# 2       20110101001302  Burglary/B&E                                  ...
# 3       20110101001302  Burglary/B&E                                  ...
# 4       20110101001302  Burglary/B&E                                  ...
# ...                ...                                                ...
# 854924  20161231235500  Burglary/B&E                                  ...
# 854925  20161231235500  Burglary/B&E                                  ...
# 854926  20161231235500  Burglary/B&E                                  ...
# 854927  20161231235500  Burglary/B&E                                  ...
# 854928  20161231235500  Burglary/B&E                                  ...
#
#           Location_Type Incident_From_Date  Incident_From_Time Zipcode  \
# ...

# %%
combined_df = combined_df.rename(columns={' Incident_From_Time':'Incident_Time'})
combined_df = combined_df.rename(columns={'Incident_From_Date':'Incident_Date'})
combined_df = combined_df.rename(columns={'NIBRS_Hi_Class':'Property_Crimes'})

combined_df
# Out:
#           Complaint_No                                    Property_Crimes  \
# 0       20110101000308  Drug Equipment Violations                     ...
# 1       20110101000700  Aggravated Assault                            ...
# 2       20110101001302  Burglary/B&E                                  ...
# 3       20110101001302  Burglary/B&E                                  ...
# 4       20110101001302  Burglary/B&E                                  ...
# ...                ...                                                ...
# 854924  20161231235500  Burglary/B&E                                  ...
# 854925  20161231235500  Burglary/B&E                                  ...
# 854926  20161231235500  Burglary/B&E                                  ...
# 854927  20161231235500  Burglary/B&E                                  ...
# 854928  20161231235500  Burglary/B&E                                  ...
#
#           Location_Type Incident_Date Incident_Time Zipcode Property_No  \
# ...

# %%
for col in combined_df.columns:
    if combined_df[col].dtype == 'object':
        combined_df[col] = combined_df[col].str.strip()

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 854929 entries, 0 to 854928
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Complaint_No      854929 non-null  object
#  1   Property_Crimes   854929 non-null  object
#  2   Location_Type     854929 non-null  object
#  3   Incident_Date     854929 non-null  object
#  4   Incident_Time     764376 non-null  object
#  5   Zipcode           854929 non-null  object
#  6   Property_No       736499 non-null  object
#  7   Property_type     736499 non-null  object
#  8   Property_Desc     736499 non-null  object
#  9   2010 Pop          854929 non-null  object
#  10  Workforce Growth  0 non-null       object
#  11  ID Gender         0 non-null       object
#  12  Median Earnings   0 non-null       object
#  13  Race              0 non-null       object
#  14  Ethnicity         0 non-null       object
# dtypes: object(15)
# memory usage: 97.8+ MB

# %%
combined_df['Incident_Date_datetime'] = pd.to_datetime(combined_df['Incident_Date'], errors='coerce')

# %%
combined_df['Incident_Time'] = combined_df['Incident_Time'].astype(str)
combined_df['Incident_Time'] = combined_df['Incident_Time'].str.strip()
combined_df['Incident_Time'] = combined_df['Incident_Time'].apply(lambda x: '0'+x if len(x) == 3 else x)
combined_df['Incident_Time'] = combined_df['Incident_Time'].apply(lambda x: '00'+x if len(x) == 2 else x)
combined_df['Incident_Time'] = combined_df['Incident_Time'].apply(lambda x: '000'+x if len(x) == 1 else x)
combined_df['Incident_Time'] = pd.to_numeric(combined_df['Incident_Time'], errors='coerce')

# %%
combined_df['Incident_Time_time'] = pd.to_datetime(combined_df['Incident_Time'],format= '%H%M',errors='coerce').dt.time
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 854929 entries, 0 to 854928
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Complaint_No            854929 non-null  object
#  1   Property_Crimes         854929 non-null  object
#  2   Location_Type           854929 non-null  object
#  3   Incident_Date           854929 non-null  object
#  4   Incident_Time           764376 non-null  float64
#  5   Zipcode                 854929 non-null  object
#  6   Property_No             736499 non-null  object
#  7   Property_type           736499 non-null  object
#  8   Property_Desc           736499 non-null  object
#  9   2010 Pop                854929 non-null  object
#  10  Workforce Growth        0 non-null       object
#  11  ID Gender               0 non-null       object
#  12  Median Earnings         0 non-null       object
#  13  Race                    0 non-null       object
# ...

# %%
combined_df = combined_df.dropna(subset=['Incident_Date_datetime','Incident_Time_time'])
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 720322 entries, 90553 to 854928
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Complaint_No            720322 non-null  object
#  1   Property_Crimes         720322 non-null  object
#  2   Location_Type           720322 non-null  object
#  3   Incident_Date           720322 non-null  object
#  4   Incident_Time           720322 non-null  float64
#  5   Zipcode                 720322 non-null  object
#  6   Property_No             623181 non-null  object
#  7   Property_type           623181 non-null  object
#  8   Property_Desc           623181 non-null  object
#  9   2010 Pop                720322 non-null  object
#  10  Workforce Growth        0 non-null       object
#  11  ID Gender               0 non-null       object
#  12  Median Earnings         0 non-null       object
#  13  Race                    0 non-null       object
# ...

# %%
combined_df['Incident_datetime'] = combined_df.apply(lambda x: pd.datetime.combine(x['Incident_Date_datetime'],x["Incident_Time_time"]), axis = 1)
combined_df
# Out:
# C:\Users\Trevor\AppData\Local\Temp\ipykernel_6788\2503011183.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   combined_df['Incident_datetime'] = combined_df.apply(lambda x: pd.datetime.combine(x['Incident_Date_datetime'],x["Incident_Time_time"]), axis = 1)
# C:\Users\Trevor\AppData\Local\Temp\ipykernel_6788\2503011183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Incident_datetime'] = combined_df.apply(lambda x: pd.datetime.combine(x['Incident_Date_datetime'],x["Incident_Time_time"]), axis = 1)
#           Complaint_No                            Property_Crimes  \
# ...

# %%
combined_df.drop(['Incident_Date_datetime','Incident_Time_time','Incident_Date','Incident_Time'], axis=1, inplace=True)
# Out:
# C:\Users\Trevor\AppData\Local\Temp\ipykernel_6788\188114727.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df.drop(['Incident_Date_datetime','Incident_Time_time','Incident_Date','Incident_Time'], axis=1, inplace=True)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 720322 entries, 90553 to 854928
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Complaint_No       720322 non-null  object
#  1   Property_Crimes    720322 non-null  object
#  2   Location_Type      720322 non-null  object
#  3   Zipcode            720322 non-null  object
#  4   Property_No        623181 non-null  object
#  5   Property_type      623181 non-null  object
#  6   Property_Desc      623181 non-null  object
#  7   2010 Pop           720322 non-null  object
#  8   Workforce Growth   0 non-null       object
#  9   ID Gender          0 non-null       object
#  10  Median Earnings    0 non-null       object
#  11  Race               0 non-null       object
#  12  Ethnicity          0 non-null       object
#  13  Incident_datetime  720322 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(13)
# memory usage: 82.4+ MB

# %%
# List of property crimes to keep
property_crimes_to_keep = [
    'Burglary/B&E', 'Theft', 'Motor Vehicle Theft', 'Theft from Motor Vehicle',
    'All other Thefts', 'Theft of Motor Vehicle Parts from Vehicle',
    'Theft from Building', 'Theft from Coin Operated Machinery', 'Arson',
    'Damage/ Vandalism to Property', 'Shoplifting', 'Embezzlement'
]

Property_df = combined_df[combined_df['Property_Crimes'].isin(property_crimes_to_keep)]
Property_df
# Out:
#           Complaint_No                            Property_Crimes  \
# 90554   20120616144400  Theft of Motor Vehicle Parts from Vehicle
# 90555   20120616144400  Theft of Motor Vehicle Parts from Vehicle
# 90565   20120616154500  Theft of Motor Vehicle Parts from Vehicle
# 90566   20120616154500  Theft of Motor Vehicle Parts from Vehicle
# 90571   20120616155601                               Burglary/B&E
# ...                ...                                        ...
# 854924  20161231235500                               Burglary/B&E
# 854925  20161231235500                               Burglary/B&E
# 854926  20161231235500                               Burglary/B&E
# 854927  20161231235500                               Burglary/B&E
# 854928  20161231235500                               Burglary/B&E
#
#        Location_Type Zipcode Property_No                       Property_type  \
# 90554    Parking Lot   28205           1                         Vehicle Tag
# ...

# %%
Property_df.to_csv("PropertyCrimes_CLEAN.csv", index=False)
