# %%
import pandas as pd
import datetime as dt

# %%
weather = pd.read_csv('weather_alerts_grouped.csv')
weather['END_DATETIME'] = pd.to_datetime(weather['END_DATETIME'])
weather['BEGIN_DATETIME'] = pd.to_datetime(weather['BEGIN_DATETIME'])

# %%
crime = pd.read_csv('PropertyCrimes_CLEAN.csv')
crime['Incident_datetime'] = pd.to_datetime(crime['Incident_datetime'])

# %%
#extract date from datetime for both crimes and weather
weather['DATE'] = weather['BEGIN_DATETIME'].dt.date
crime['DATE'] = crime['Incident_datetime'].dt.date

# %%
crime_weather = pd.merge(crime, weather, on='DATE', how='left')
crime_weather[crime_weather['EVENT_TYPE'].notnull()]
# Out:
#           Complaint_No      Property_Crimes Location_Type  Zipcode  \
# 1807    20120621122401  Motor Vehicle Theft   Parking Lot    28217
# 1808    20120621122401  Motor Vehicle Theft   Parking Lot    28217
# 5392    20120701013000         Burglary/B&E      Outdoors    28215
# 5393    20120701013000         Burglary/B&E      Outdoors    28215
# 5394    20120701013000         Burglary/B&E      Outdoors    28215
# ...                ...                  ...           ...      ...
# 339058  20161202144902         Burglary/B&E         Other    28203
# 339059  20161202144902         Burglary/B&E         Other    28203
# 339060  20161202144902         Burglary/B&E         Other    28203
# 339694  20161208094902          Shoplifting       Indoors    28273
# 339861  20161209130000         Embezzlement       Indoors    28210
#
#         Property_No           Property_type         Property_Desc  2010 Pop  \
# 1807            1.0              Automobile    Vehicles and Parts     24199
# 1808            1.0              Automobile    Vehicles and Parts     24199
# 5392            1.0                 Windows            Structures     53629
# 5393            1.0                 Windows            Structures     53629
# 5394            1.0                 Windows            Structures     53629
# ...             ...                     ...                   ...       ...
# 339058          2.0  Tools (Power and Hand)         Miscellaneous     11315
# 339059          3.0  Tools (Power and Hand)         Miscellaneous     11315
# 339060          4.0                   Other        Other Property     11315
# 339694          1.0                   Other        Other Property     31478
# 339861          1.0              Money/Cash  Money and Securities     42256
#
#         Median Household Income  Victim_Age  ...      BEGIN_DATETIME  \
# 1807                    55075.0         NaN  ... 2012-05-22 21:30:00
# 1808                    55075.0         NaN  ... 2012-05-22 21:30:00
# 5392                    55578.0        46.0  ... 2012-07-01 17:35:00
# 5393                    55578.0        46.0  ... 2012-07-01 17:30:00
# 5394                    55578.0        46.0  ... 2012-07-01 17:21:00
# ...                         ...         ...  ...                 ...
# 339058                  91567.0        39.0  ... 2016-11-30 18:26:00
# 339059                  91567.0        39.0  ... 2016-11-30 18:26:00
# 339060                  91567.0        39.0  ... 2016-11-30 18:26:00
# 339694                  75126.0         NaN  ... 2016-11-30 18:26:00
# 339861                  79403.0         NaN  ... 2016-11-30 18:26:00
#
#               END_DATETIME  BEGIN_LAT  BEGIN_LON    END_LAT    END_LON  \
# 1807   2012-05-22 21:45:00  35.150000 -80.885000  35.150000 -80.885000
# 1808   2012-05-22 21:45:00  35.150000 -80.885000  35.150000 -80.885000
# 5392   2012-07-01 17:51:00  35.133333 -80.740767  35.133333 -80.740767
# 5393   2012-07-01 17:45:00  35.340000 -80.810000  35.340000 -80.810000
# 5394   2012-07-01 17:40:00  35.320000 -80.800000  35.180000 -80.655000
# ...                    ...        ...        ...        ...        ...
# 339058 2016-11-30 18:29:00  35.124000 -80.953000  35.143000 -80.918000
# 339059 2016-11-30 18:29:00  35.124000 -80.953000  35.143000 -80.918000
# 339060 2016-11-30 18:29:00  35.124000 -80.953000  35.143000 -80.918000
# 339694 2016-11-30 18:29:00  35.124000 -80.953000  35.143000 -80.918000
# 339861 2016-11-30 18:29:00  35.124000 -80.953000  35.143000 -80.918000
#
#               time_diff     EVENT_TYPE_col      date.1  weather_id
# 1807    0 days 00:15:00          Lightning  2012-05-22        58.0
# 1808    0 days 00:15:00          Lightning  2012-05-22        58.0
# 5392    0 days 00:16:00               Hail  2012-07-01        30.0
# 5393    0 days 00:15:00          Lightning  2012-07-01        59.0
# 5394    0 days 00:19:00  Thunderstorm Wind  2012-07-01        82.0
# ...                 ...                ...         ...         ...
# 339058  0 days 00:03:00            Tornado  2016-11-30       135.0
# 339059  0 days 00:03:00            Tornado  2016-11-30       135.0
# 339060  0 days 00:03:00            Tornado  2016-11-30       135.0
# 339694  0 days 00:03:00            Tornado  2016-11-30       135.0
# 339861  0 days 00:03:00            Tornado  2016-11-30       135.0
#
# [44581 rows x 26 columns]

# %%
crime_weather
# Out:
#           Complaint_No                            Property_Crimes  \
# 0       20120616144400  Theft of Motor Vehicle Parts from Vehicle
# 1       20120616144400  Theft of Motor Vehicle Parts from Vehicle
# 2       20120616144400  Theft of Motor Vehicle Parts from Vehicle
# 3       20120616144400  Theft of Motor Vehicle Parts from Vehicle
# 4       20120616154500  Theft of Motor Vehicle Parts from Vehicle
# ...                ...                                        ...
# 341837  20161231235500                               Burglary/B&E
# 341838  20161231235500                               Burglary/B&E
# 341839  20161231235500                               Burglary/B&E
# 341840  20161231235500                               Burglary/B&E
# 341841  20161231235500                               Burglary/B&E
#
#        Location_Type  Zipcode  Property_No  \
# 0        Parking Lot    28205          1.0
# 1        Parking Lot    28205          1.0
# 2        Parking Lot    28205          1.0
# 3        Parking Lot    28205          1.0
# 4        Parking Lot    28212          1.0
# ...              ...      ...          ...
# 341837       Indoors    28208          1.0
# 341838       Indoors    28208          2.0
# 341839       Indoors    28208          3.0
# 341840       Indoors    28208          4.0
# 341841       Indoors    28208          5.0
#
#                              Property_type  \
# 0                              Vehicle Tag
# 1                              Vehicle Tag
# 2                              Vehicle Tag
# 3                              Vehicle Tag
# 4                              Vehicle Tag
# ...                                    ...
# 341837                        TV Equipment
# 341838                        TV Equipment
# 341839  Video Game Systems and Accessories
# 341840                     Tablet Computer
# 341841                        TV Equipment
#
#                                Property_Desc  2010 Pop  \
# 0                         Vehicles and Parts     43931
# 1                         Vehicles and Parts     43931
# 2                         Vehicles and Parts     43931
# 3                         Vehicles and Parts     43931
# 4                         Vehicles and Parts     38457
# ...                                      ...       ...
# 341837  Electronic Equipment and Accessories     34156
# 341838  Electronic Equipment and Accessories     34156
# 341839  Electronic Equipment and Accessories     34156
# 341840  Electronic Equipment and Accessories     34156
# 341841  Electronic Equipment and Accessories     34156
#
#         Median Household Income  Victim_Age  ... BEGIN_DATETIME END_DATETIME  \
# 0                       61525.0        26.0  ...            NaT          NaT
# 1                       61525.0        26.0  ...            NaT          NaT
# 2                       61525.0        26.0  ...            NaT          NaT
# 3                       61525.0        26.0  ...            NaT          NaT
# 4                       44747.0        61.0  ...            NaT          NaT
# ...                         ...         ...  ...            ...          ...
# 341837                  44711.0        42.0  ...            NaT          NaT
# 341838                  44711.0        42.0  ...            NaT          NaT
# 341839                  44711.0        42.0  ...            NaT          NaT
# 341840                  44711.0        42.0  ...            NaT          NaT
# 341841                  44711.0        42.0  ...            NaT          NaT
#
#        BEGIN_LAT BEGIN_LON END_LAT END_LON time_diff EVENT_TYPE_col  date.1  \
# 0            NaN       NaN     NaN     NaN       NaN            NaN     NaN
# 1            NaN       NaN     NaN     NaN       NaN            NaN     NaN
# 2            NaN       NaN     NaN     NaN       NaN            NaN     NaN
# 3            NaN       NaN     NaN     NaN       NaN            NaN     NaN
# 4            NaN       NaN     NaN     NaN       NaN            NaN     NaN
# ...          ...       ...     ...     ...       ...            ...     ...
# 341837       NaN       NaN     NaN     NaN       NaN            NaN     NaN
# 341838       NaN       NaN     NaN     NaN       NaN            NaN     NaN
# 341839       NaN       NaN     NaN     NaN       NaN            NaN     NaN
# 341840       NaN       NaN     NaN     NaN       NaN            NaN     NaN
# 341841       NaN       NaN     NaN     NaN       NaN            NaN     NaN
#
#         weather_id
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 341837         NaN
# 341838         NaN
# 341839         NaN
# 341840         NaN
# 341841         NaN
#
# [341842 rows x 26 columns]

# %%
#check if the Incident_datetime is within the weather alert window
crime_weather['in_window'] = (crime_weather['Incident_datetime'] > crime_weather['BEGIN_DATETIME'])
crime_weather[crime_weather['in_window']]
# Out:
#           Complaint_No Property_Crimes Location_Type  Zipcode  Property_No  \
# 5810    20120701220002     Shoplifting       Indoors    28216          1.0
# 5811    20120701220002     Shoplifting       Indoors    28216          1.0
# 5812    20120701220002     Shoplifting       Indoors    28216          1.0
# 5813    20120701220002     Shoplifting       Indoors    28216          1.0
# 5814    20120701220002     Shoplifting       Indoors    28216          1.0
# ...                ...             ...           ...      ...          ...
# 339057  20161202144902    Burglary/B&E         Other    28203          1.0
# 339058  20161202144902    Burglary/B&E         Other    28203          2.0
# 339059  20161202144902    Burglary/B&E         Other    28203          3.0
# 339060  20161202144902    Burglary/B&E         Other    28203          4.0
# 339694  20161208094902     Shoplifting       Indoors    28273          1.0
#
#                  Property_type     Property_Desc  2010 Pop  \
# 5810        Alcoholic Beverage  Consumable Goods     47227
# 5811        Alcoholic Beverage  Consumable Goods     47227
# 5812        Alcoholic Beverage  Consumable Goods     47227
# 5813        Alcoholic Beverage  Consumable Goods     47227
# 5814        Alcoholic Beverage  Consumable Goods     47227
# ...                        ...               ...       ...
# 339057  Tools (Power and Hand)     Miscellaneous     11315
# 339058  Tools (Power and Hand)     Miscellaneous     11315
# 339059  Tools (Power and Hand)     Miscellaneous     11315
# 339060                   Other    Other Property     11315
# 339694                   Other    Other Property     31478
#
#         Median Household Income  Victim_Age  ...        END_DATETIME  \
# 5810                    53462.0         NaN  ... 2012-07-01 17:51:00
# 5811                    53462.0         NaN  ... 2012-07-01 17:45:00
# 5812                    53462.0         NaN  ... 2012-07-01 17:40:00
# 5813                    53462.0         NaN  ... 2012-07-01 17:51:00
# 5814                    53462.0         NaN  ... 2012-07-01 17:45:00
# ...                         ...         ...  ...                 ...
# 339057                  91567.0        39.0  ... 2016-11-30 18:29:00
# 339058                  91567.0        39.0  ... 2016-11-30 18:29:00
# 339059                  91567.0        39.0  ... 2016-11-30 18:29:00
# 339060                  91567.0        39.0  ... 2016-11-30 18:29:00
# 339694                  75126.0         NaN  ... 2016-11-30 18:29:00
#
#         BEGIN_LAT  BEGIN_LON    END_LAT    END_LON        time_diff  \
# 5810    35.133333 -80.740767  35.133333 -80.740767  0 days 00:16:00
# 5811    35.340000 -80.810000  35.340000 -80.810000  0 days 00:15:00
# 5812    35.320000 -80.800000  35.180000 -80.655000  0 days 00:19:00
# 5813    35.133333 -80.740767  35.133333 -80.740767  0 days 00:16:00
# 5814    35.340000 -80.810000  35.340000 -80.810000  0 days 00:15:00
# ...           ...        ...        ...        ...              ...
# 339057  35.124000 -80.953000  35.143000 -80.918000  0 days 00:03:00
# 339058  35.124000 -80.953000  35.143000 -80.918000  0 days 00:03:00
# 339059  35.124000 -80.953000  35.143000 -80.918000  0 days 00:03:00
# 339060  35.124000 -80.953000  35.143000 -80.918000  0 days 00:03:00
# 339694  35.124000 -80.953000  35.143000 -80.918000  0 days 00:03:00
#
#            EVENT_TYPE_col      date.1  weather_id  in_window
# 5810                 Hail  2012-07-01        30.0       True
# 5811            Lightning  2012-07-01        59.0       True
# 5812    Thunderstorm Wind  2012-07-01        82.0       True
# 5813                 Hail  2012-07-01        30.0       True
# 5814            Lightning  2012-07-01        59.0       True
# ...                   ...         ...         ...        ...
# 339057            Tornado  2016-11-30       135.0       True
# 339058            Tornado  2016-11-30       135.0       True
# 339059            Tornado  2016-11-30       135.0       True
# 339060            Tornado  2016-11-30       135.0       True
# 339694            Tornado  2016-11-30       135.0       True
#
# [32637 rows x 27 columns]

# %%
crime_weather.columns
# Out:
# Index(['Complaint_No', 'Property_Crimes', 'Location_Type', 'Zipcode',
#        'Property_No', 'Property_type', 'Property_Desc', '2010 Pop',
#        'Median Household Income', 'Victim_Age', 'Victim_Gender',
#        'Victim_Ethnic', 'Incident_datetime', 'DATE', 'EVENT_TYPE', 'date',
#        'BEGIN_DATETIME', 'END_DATETIME', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT',
#        'END_LON', 'time_diff', 'EVENT_TYPE_col', 'date.1', 'weather_id',
#        'in_window'],
#       dtype='object')

# %%
crime_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341842 entries, 0 to 341841
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Complaint_No             341842 non-null  int64
#  1   Property_Crimes          341842 non-null  object
#  2   Location_Type            341842 non-null  object
#  3   Zipcode                  341842 non-null  int64
#  4   Property_No              340209 non-null  float64
#  5   Property_type            340209 non-null  object
#  6   Property_Desc            340209 non-null  object
#  7   2010 Pop                 341842 non-null  int64
#  8   Median Household Income  341842 non-null  float64
#  9   Victim_Age               209831 non-null  float64
#  10  Victim_Gender            242767 non-null  object
#  11  Victim_Ethnic            242767 non-null  object
#  12  Incident_datetime        341842 non-null  datetime64[ns]
#  13  DATE                     341842 non-null  object
#  14  EVENT_TYPE               44581 non-null   object
#  15  date                     44581 non-null   object
#  16  BEGIN_DATETIME           44581 non-null   datetime64[ns]
#  17  END_DATETIME             44581 non-null   datetime64[ns]
#  18  BEGIN_LAT                44581 non-null   float64
#  19  BEGIN_LON                44581 non-null   float64
#  20  END_LAT                  44581 non-null   float64
#  21  END_LON                  44581 non-null   float64
#  22  time_diff                44581 non-null   object
#  23  EVENT_TYPE_col           44581 non-null   object
#  24  date.1                   44581 non-null   object
#  25  weather_id               44581 non-null   float64
#  26  in_window                341842 non-null  bool
# dtypes: bool(1), datetime64[ns](3), float64(8), int64(3), object(12)
# memory usage: 70.7+ MB

# %%
crime_weather.drop(['date','date.1','EVENT_TYPE_col','Incident_datetime','BEGIN_DATETIME','END_DATETIME'], axis=1, inplace=True)
crime_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341842 entries, 0 to 341841
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Complaint_No             341842 non-null  int64
#  1   Property_Crimes          341842 non-null  object
#  2   Location_Type            341842 non-null  object
#  3   Zipcode                  341842 non-null  int64
#  4   Property_No              340209 non-null  float64
#  5   Property_type            340209 non-null  object
#  6   Property_Desc            340209 non-null  object
#  7   2010 Pop                 341842 non-null  int64
#  8   Median Household Income  341842 non-null  float64
#  9   Victim_Age               209831 non-null  float64
#  10  Victim_Gender            242767 non-null  object
#  11  Victim_Ethnic            242767 non-null  object
#  12  DATE                     341842 non-null  object
#  13  EVENT_TYPE               44581 non-null   object
#  14  BEGIN_LAT                44581 non-null   float64
#  15  BEGIN_LON                44581 non-null   float64
#  16  END_LAT                  44581 non-null   float64
#  17  END_LON                  44581 non-null   float64
#  18  time_diff                44581 non-null   object
#  19  weather_id               44581 non-null   float64
#  20  in_window                341842 non-null  bool
# dtypes: bool(1), float64(8), int64(3), object(9)
# memory usage: 55.1+ MB

# %%
crime_weather.nunique()
# Out:
# Complaint_No               53968
# Property_Crimes                6
# Location_Type                  5
# Zipcode                       24
# Property_No                  110
# Property_type                 63
# Property_Desc                 13
# 2010 Pop                      24
# Median Household Income       24
# Victim_Age                    99
# Victim_Gender                  3
# Victim_Ethnic                 47
# DATE                        1941
# EVENT_TYPE                     7
# BEGIN_LAT                     73
# BEGIN_LON                     67
# END_LAT                       63
# END_LON                       67
# time_diff                     38
# weather_id                   107
# in_window                      2
# dtype: int64

# %%
crime_weather.drop_duplicates(inplace=True)

# %%
crime_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169595 entries, 0 to 341841
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Complaint_No             169595 non-null  int64
#  1   Property_Crimes          169595 non-null  object
#  2   Location_Type            169595 non-null  object
#  3   Zipcode                  169595 non-null  int64
#  4   Property_No              168316 non-null  float64
#  5   Property_type            168316 non-null  object
#  6   Property_Desc            168316 non-null  object
#  7   2010 Pop                 169595 non-null  int64
#  8   Median Household Income  169595 non-null  float64
#  9   Victim_Age               82848 non-null   float64
#  10  Victim_Gender            85326 non-null   object
#  11  Victim_Ethnic            85326 non-null   object
#  12  DATE                     169595 non-null  object
#  13  EVENT_TYPE               10163 non-null   object
#  14  BEGIN_LAT                10163 non-null   float64
#  15  BEGIN_LON                10163 non-null   float64
#  16  END_LAT                  10163 non-null   float64
#  17  END_LON                  10163 non-null   float64
#  18  time_diff                10163 non-null   object
#  19  weather_id               10163 non-null   float64
#  20  in_window                169595 non-null  bool
# dtypes: bool(1), float64(8), int64(3), object(9)
# memory usage: 27.3+ MB

# %%
#if in_window is False, then set EVENT_TYPE to null
crime_weather.loc[crime_weather['in_window'] == False, 'EVENT_TYPE'] = None

# %%
#drop in_window column
crime_weather.drop(['in_window'], axis=1, inplace=True)
crime_weather
# Out:
#           Complaint_No                            Property_Crimes  \
# 0       20120616144400  Theft of Motor Vehicle Parts from Vehicle
# 4       20120616154500  Theft of Motor Vehicle Parts from Vehicle
# 8       20120616155601                               Burglary/B&E
# 10      20120616155601                               Burglary/B&E
# 16      20120616162302                               Burglary/B&E
# ...                ...                                        ...
# 341837  20161231235500                               Burglary/B&E
# 341838  20161231235500                               Burglary/B&E
# 341839  20161231235500                               Burglary/B&E
# 341840  20161231235500                               Burglary/B&E
# 341841  20161231235500                               Burglary/B&E
#
#        Location_Type  Zipcode  Property_No  \
# 0        Parking Lot    28205          1.0
# 4        Parking Lot    28212          1.0
# 8            Indoors    28213          1.0
# 10           Indoors    28213          2.0
# 16           Indoors    28208          1.0
# ...              ...      ...          ...
# 341837       Indoors    28208          1.0
# 341838       Indoors    28208          2.0
# 341839       Indoors    28208          3.0
# 341840       Indoors    28208          4.0
# 341841       Indoors    28208          5.0
#
#                              Property_type  \
# 0                              Vehicle Tag
# 4                              Vehicle Tag
# 8                               Money/Cash
# 10                                   Other
# 16                            TV Equipment
# ...                                    ...
# 341837                        TV Equipment
# 341838                        TV Equipment
# 341839  Video Game Systems and Accessories
# 341840                     Tablet Computer
# 341841                        TV Equipment
#
#                                Property_Desc  2010 Pop  \
# 0                         Vehicles and Parts     43931
# 4                         Vehicles and Parts     38457
# 8                       Money and Securities     37309
# 10                             Miscellaneous     37309
# 16      Electronic Equipment and Accessories     34156
# ...                                      ...       ...
# 341837  Electronic Equipment and Accessories     34156
# 341838  Electronic Equipment and Accessories     34156
# 341839  Electronic Equipment and Accessories     34156
# 341840  Electronic Equipment and Accessories     34156
# 341841  Electronic Equipment and Accessories     34156
#
#         Median Household Income  Victim_Age Victim_Gender  \
# 0                       61525.0        26.0             F
# 4                       44747.0        61.0             M
# 8                       49714.0        61.0             M
# 10                      49714.0        61.0             M
# 16                      44711.0        31.0             F
# ...                         ...         ...           ...
# 341837                  44711.0        42.0             M
# 341838                  44711.0        42.0             M
# 341839                  44711.0        42.0             M
# 341840                  44711.0        42.0             M
# 341841                  44711.0        42.0             M
#
#                                           Victim_Ethnic        DATE  \
# 0        White                          Unknown/Refused  2012-06-15
# 4       Black                          Other/Not Listed  2012-06-15
# 8       Black                          Other/Not Listed  2012-06-16
# 10      Black                          Other/Not Listed  2012-06-16
# 16      Black                          Other/Not Listed  2012-06-16
# ...                                                 ...         ...
# 341837  White                          Other/Not Listed  2016-12-31
# 341838  White                          Other/Not Listed  2016-12-31
# 341839  White                          Other/Not Listed  2016-12-31
# 341840  White                          Other/Not Listed  2016-12-31
# 341841  White                          Other/Not Listed  2016-12-31
#
#        EVENT_TYPE  BEGIN_LAT  BEGIN_LON  END_LAT  END_LON time_diff  \
# 0            None        NaN        NaN      NaN      NaN       NaN
# 4            None        NaN        NaN      NaN      NaN       NaN
# 8            None        NaN        NaN      NaN      NaN       NaN
# 10           None        NaN        NaN      NaN      NaN       NaN
# 16           None        NaN        NaN      NaN      NaN       NaN
# ...           ...        ...        ...      ...      ...       ...
# 341837       None        NaN        NaN      NaN      NaN       NaN
# 341838       None        NaN        NaN      NaN      NaN       NaN
# 341839       None        NaN        NaN      NaN      NaN       NaN
# 341840       None        NaN        NaN      NaN      NaN       NaN
# 341841       None        NaN        NaN      NaN      NaN       NaN
#
#         weather_id
# 0              NaN
# 4              NaN
# 8              NaN
# 10             NaN
# 16             NaN
# ...            ...
# 341837         NaN
# 341838         NaN
# 341839         NaN
# 341840         NaN
# 341841         NaN
#
# [169595 rows x 20 columns]

# %%
crime_no_weather = crime_weather[crime_weather['EVENT_TYPE'].isnull()].copy()

# %%
crime_extreme_weather = crime_weather[crime_weather['EVENT_TYPE'].notnull()].copy()

# %%
#export to csv in Data_files folder
crime_weather.to_csv('crime_weather_all_CLEANED.csv')
crime_no_weather.to_csv('crime_no_weather_CLEANED.csv')
crime_extreme_weather.to_csv('crime_extreme_weather_CLEANED.csv')
